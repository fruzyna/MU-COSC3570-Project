# %%
import pandas as pd

# %%
crimes = pd.read_csv('data/crimes.csv', ',', parse_dates = True, index_col='ID')
crimes.head()
# Out:
#          Case Number                    Date                   Block  IUCR  \
# ID
# 10000092    HY189866  03/18/2015 07:44:00 PM         047XX W OHIO ST  041A
# 10000094    HY190059  03/18/2015 11:00:00 PM  066XX S MARSHFIELD AVE  4625
# 10000095    HY190052  03/18/2015 10:45:00 PM   044XX S LAKE PARK AVE  0486
# 10000096    HY190054  03/18/2015 10:30:00 PM    051XX S MICHIGAN AVE  0460
# 10000097    HY189976  03/18/2015 09:00:00 PM        047XX W ADAMS ST  031A
#
#            Primary Type              Description Location Description  Arrest  \
# ID
# 10000092        BATTERY      AGGRAVATED: HANDGUN               STREET   False
# 10000094  OTHER OFFENSE         PAROLE VIOLATION               STREET    True
# 10000095        BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 10000096        BATTERY                   SIMPLE            APARTMENT   False
# 10000097        ROBBERY           ARMED: HANDGUN             SIDEWALK   False
#
# ...

# %%
crimeplaces = crimes['Location Description'].value_counts()
ax = crimeplaces[:25].plot(kind='bar', figsize=(10, 5))
ax.set_xlabel('Location Description')
ax.set_ylabel('Instances')
ax.set_title('Top 25 Most Common Location Descriptions')
ax.get_figure().savefig('plots/top25-crimelocs.png')

# %%
crimes.loc[crimes['Location Description'] == 'LAGOON']
# Out:
#       Case Number                    Date                Block  IUCR  \
# ID
# 23033    HZ446129  09/23/2016 12:01:00 PM  021XX W PERSHING RD  0110
#
#       Primary Type          Description Location Description  Arrest  \
# ID
# 23033     HOMICIDE  FIRST DEGREE MURDER               LAGOON   False
#
#        Domestic  Beat    ...     Ward  Community Area  FBI Code X Coordinate  \
# ID                       ...
# 23033     False   912    ...     11.0            59.0       01A          NaN
#
#        Y Coordinate  Year              Updated On Latitude  Longitude  \
# ID
# 23033           NaN  2016  12/24/2016 03:50:13 PM      NaN        NaN
#
#        Location
# ID
# 23033       NaN
#
# [1 rows x 21 columns]

# %%
traffichist = pd.read_csv('data/traffic_historical.csv', ',', parse_dates = True, index_col='ID', na_values=-1)
traffichist.head()
# Out:
#                                                             TIME  SEGMENTID  \
# ID
# a9b36413b0bd50d9cb8f53e32972ac6e4fa8d315  01/16/2013 11:50:32 PM        116
# 26b44d4117c8bae8791703afbe59c4f9f13a28be  02/24/2013 11:50:32 PM         54
# 89a5fc3a547476a516385530060a9a147f51e0e4  02/17/2013 11:50:32 PM        597
# 6a9e4f5a26694e1615928dbc78d92daee4f26045  02/23/2013 11:50:32 PM        363
# 44cf8541a4c252d6f74519aed680aa2c0de7dda0  12/01/2014 11:50:32 PM        203
#
#                                           BUS COUNT                  \
# ID
# a9b36413b0bd50d9cb8f53e32972ac6e4fa8d315                        2.0
# 26b44d4117c8bae8791703afbe59c4f9f13a28be                        2.0
# 89a5fc3a547476a516385530060a9a147f51e0e4                        0.0
# 6a9e4f5a26694e1615928dbc78d92daee4f26045                        1.0
# 44cf8541a4c252d6f74519aed680aa2c0de7dda0                        0.0
#
#                                           MESSAGE COUNT  SPEED
# ID
# ...

# %%
traffichist['SEGMENTID'].value_counts()
# Out:
# 1309    11615
# 360     11615
# 374     11615
# 373     11615
# 372     11615
# 371     11615
# 370     11615
# 369     11615
# 368     11615
# 367     11615
# 366     11615
# 365     11615
# 364     11615
# 363     11615
# 362     11615
# 361     11615
# 359     11615
# 343     11615
# 358     11615
# 357     11615
# 356     11615
# 355     11615
# 354     11615
# 353     11615
# 352     11615
# 351     11615
# 350     11615
# 349     11615
# 348     11615
# 347     11615
#         ...
# 791     11615
# 790     11615
# 808     11615
# 789     11615
# 788     11615
# 800     11615
# 735        99
# 999        99
# 998        99
# 1002       99
# 1014       99
# 1123       99
# 164        99
# 1047       99
# 167        99
# 1064       99
# 1048       99
# 958        99
# 676        99
# 1284       99
# 677        99
# 613        99
# 1279       99
# 1278       99
# 1194       99
# 1195       99
# 1275       99
# 523        99
# 1046       99
# 524        99
# ...

# %%
nonatraf = traffichist.dropna()
seg_counts = nonatraf['SEGMENTID'].value_counts()
ax = seg_counts.plot(kind='bar', figsize=(40, 20))
ax.set_xlabel('Segment')
ax.set_ylabel('Reports')
ax.set_title('Total Reports by Segment')
ax.get_figure().savefig('plots/reports-by-segment.png')

# %%
weather = pd.read_csv('data/weather.csv', ',', parse_dates = True, index_col='Measurement ID')
weather.head()
# Out:
#                                                    Station Name  \
# Measurement ID
# OakStreetWeatherStation201505221500  Oak Street Weather Station
# OakStreetWeatherStation201505221700  Oak Street Weather Station
# OakStreetWeatherStation201505221800  Oak Street Weather Station
# OakStreetWeatherStation201505221900  Oak Street Weather Station
# OakStreetWeatherStation201505222000  Oak Street Weather Station
#
#                                       Measurement Timestamp  Air Temperature  \
# Measurement ID
# OakStreetWeatherStation201505221500  05/22/2015 03:00:00 PM              NaN
# OakStreetWeatherStation201505221700  05/22/2015 05:00:00 PM              NaN
# OakStreetWeatherStation201505221800  05/22/2015 06:00:00 PM              NaN
# OakStreetWeatherStation201505221900  05/22/2015 07:00:00 PM              NaN
# OakStreetWeatherStation201505222000  05/22/2015 08:00:00 PM              NaN
#
#                                      Wet Bulb Temperature  Humidity  \
# ...

# %%
weather['Measurement Timestamp'] = pd.to_datetime(weather['Measurement Timestamp'])
weather['Station Name'].value_counts()
# Out:
# Foster Weather Station         22992
# Oak Street Weather Station     21835
# 63rd Street Weather Station    21544
# Name: Station Name, dtype: int64

# %%
foster = weather.loc[weather['Station Name'] == 'Foster Weather Station'].sort_values('Measurement Timestamp')
foster
# Out:
#                                             Station Name  \
# Measurement ID
# FosterWeatherStation201505221600  Foster Weather Station
# FosterWeatherStation201505221700  Foster Weather Station
# FosterWeatherStation201505221800  Foster Weather Station
# FosterWeatherStation201505221900  Foster Weather Station
# FosterWeatherStation201505222000  Foster Weather Station
# FosterWeatherStation201505222100  Foster Weather Station
# FosterWeatherStation201505222200  Foster Weather Station
# FosterWeatherStation201505222300  Foster Weather Station
# FosterWeatherStation201505230800  Foster Weather Station
# FosterWeatherStation201505230900  Foster Weather Station
# FosterWeatherStation201505231000  Foster Weather Station
# FosterWeatherStation201505231100  Foster Weather Station
# FosterWeatherStation201505231200  Foster Weather Station
# FosterWeatherStation201505231300  Foster Weather Station
# FosterWeatherStation201505231500  Foster Weather Station
# ...

# %%
foster['Air Temperature'].dropna().plot(kind='line', y='Air Temp (Celsius)', x='Date', figsize=(25, 10))
